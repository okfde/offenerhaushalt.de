# %%
cd ../../../
# Out:
# /home/walrus/offenerhaushalt

# %%
import pandas as pd

# %%
states = pd.read_csv('German-Zip-Codes.csv', sep=';')

# %%
bundesland = states.Bundesland.unique()

# %%
import json

# %%
len(bundesland)
# Out:
# 16

# %%
states
# Out:
#                  Ort           Zusatz    Plz  Vorwahl              Bundesland
# 0               Aach          b Trier  54298    651.0         Rheinland-Pfalz
# 1               Aach          , Hegau  78267   7774.0       Baden-Württemberg
# 2             Aachen              NaN  52062    241.0     Nordrhein-Westfalen
# 3             Aachen              NaN  52064    241.0     Nordrhein-Westfalen
# 4             Aachen              NaN  52066    241.0     Nordrhein-Westfalen
# 5             Aachen              NaN  52068    241.0     Nordrhein-Westfalen
# 6             Aachen              NaN  52070    241.0     Nordrhein-Westfalen
# 7             Aachen              NaN  52072    241.0     Nordrhein-Westfalen
# 8             Aachen              NaN  52074    241.0     Nordrhein-Westfalen
# 9             Aachen              NaN  52076    241.0     Nordrhein-Westfalen
# 10            Aachen              NaN  52078    241.0     Nordrhein-Westfalen
# 11            Aachen              NaN  52080    241.0     Nordrhein-Westfalen
# 12             Aalen          , Württ  73430   7361.0       Baden-Württemberg
# 13             Aalen          , Württ  73431   7361.0       Baden-Württemberg
# 14             Aalen          , Württ  73432   7361.0       Baden-Württemberg
# 15             Aalen          , Württ  73433   7361.0       Baden-Württemberg
# 16             Aalen          , Württ  73434   7361.0       Baden-Württemberg
# 17         Aarbergen              NaN  65326   6120.0                  Hessen
# 18         Aasbüttel              NaN  25560   4892.0       Schlewig-Holstein
# 19        Abbau Ader              NaN  29416      NaN          Sachsen-Anhalt
# 20         Abbendorf        a d Havel  19322  38791.0             Brandenburg
# 21         Abbenrode    b Wernigerode  38871  39452.0          Sachsen-Anhalt
# 22          Abberode              NaN   6543  34779.0          Sachsen-Anhalt
# 23          Abenberg       , Mittelfr  91183   9178.0                  Bayern
# 24             Abend              NaN   1623  35246.0                 Sachsen
# 25         Abensberg      , Hallertau  93326   9443.0                  Bayern
# 26        Abentheuer              NaN  55767   6782.0         Rheinland-Pfalz
# 27           Abraham      , Kr Passau  94036      NaN                  Bayern
# 28           Absberg              NaN  91720   9175.0                  Bayern
# 29           Abstatt              NaN  74232   7062.0       Baden-Württemberg
# ...              ...              ...    ...      ...                     ...
# 19640         Zützen             , NL  15938  35452.0             Brandenburg
# 19641         Zützen     b Angermünde  16306   3332.0             Brandenburg
# 19642    Zuzenhausen              NaN  74939   6226.0       Baden-Württemberg
# 19643        Zwackau              NaN   7819  36481.0               Thüringen
# 19644       Zweckham              NaN  83374   8669.0                  Bayern
# 19645       Zweedorf    b Bad Doberan  18230  38294.0  Mecklenburg-Vorpommern
# 19646    Zweibrücken          , Pfalz  66482   6332.0         Rheinland-Pfalz
# 19647  Zweifelscheid              NaN  54673   6564.0         Rheinland-Pfalz
# 19648    Zweiflingen          , Württ  74639   7948.0       Baden-Württemberg
# 19649     Zweihausen  b Wismar, Meckl  23992   3841.0  Mecklenburg-Vorpommern
# 19650        Zweimen              NaN   6254  34638.0          Sachsen-Anhalt
# 19651        Zwenkau              NaN   4442  34203.0                 Sachsen
# 19652       Zwergern              NaN  82432   8858.0                  Bayern
# 19653        Zwickau              NaN   8056    375.0                 Sachsen
# 19654        Zwickau              NaN   8058    375.0                 Sachsen
# 19655        Zwickau              NaN   8060    375.0                 Sachsen
# 19656        Zwickau              NaN   8062    375.0                 Sachsen
# 19657        Zwickau              NaN   8064    375.0                 Sachsen
# 19658        Zwickau              NaN   8066    375.0                 Sachsen
# 19659     Zwickmühle              NaN  36154   6650.0                  Hessen
# 19660     Zwiefalten          , Württ  88529   7373.0       Baden-Württemberg
# 19661        Zwiesel              NaN  94227   9922.0                  Bayern
# 19662   Zwillingshof              NaN  85737     89.0                  Bayern
# 19663         Zwinge              NaN  37345  36072.0               Thüringen
# 19664    Zwingenberg        , Bergstr  64673   6251.0                  Hessen
# 19665    Zwingenberg          , Baden  69439   6263.0       Baden-Württemberg
# 19666  Zwischendeich              NaN  19322   3877.0             Brandenburg
# 19667        Zwochau      b Delitzsch   4509  34207.0                 Sachsen
# 19668        Zwönitz              NaN   8297  37754.0                 Sachsen
# 19669          Zwota              NaN   8267  37467.0                 Sachsen
#
# [19670 rows x 5 columns]

# %%
bd = {b: '' for b in bundesland}

# %%
bd['Baden-Württemberg'] = 'BW'
bd['Bayern'] = 'BY'
bd['Berlin'] = 'BE'
bd['Brandenburg'] = 'BB'
bd['Bremen'] = 'HB' 
bd['Hamburg'] = 'HH' 
bd['Hessen'] = 'HE'
bd['Mecklenburg-Vorpommern'] = 'MV'
bd['Niedersachsen'] = 'NI'
bd['Nordrhein-Westfalen'] = 'NW'
bd['Rheinland-Pfalz'] = 'RP'
bd['Saarland'] = 'SL'
bd['Sachsen'] = 'SN'
bd['Sachsen-Anhalt'] = 'ST'
bd['Schlewig-Holstein'] = 'SH'
bd['Thüringen'] = 'TH'

# %%
bd
# Out:
# {'Baden-Württemberg': 'BW',
#  'Bayern': 'BY',
#  'Berlin': 'BE',
#  'Brandenburg': 'BB',
#  'Bremen': 'HB',
#  'Hamburg': 'HH',
#  'Hessen': 'HE',
#  'Mecklenburg-Vorpommern': 'MV',
#  'Niedersachsen': 'NI',
#  'Nordrhein-Westfalen': 'NW',
#  'Rheinland-Pfalz': 'RP',
#  'Saarland': 'SL',
#  'Sachsen': 'SN',
#  'Sachsen-Anhalt': 'ST',
#  'Schlewig-Holstein': 'SH',
#  'Thüringen': 'TH'}

# %%
len(states[states.Bundesland == 'Sachsen'])
# Out:
# 1120

# %%
len(states[states.Bundesland == 'Sachsen']['Ort'].unique())
# Out:
# 961

# %%
json.dump(bd, open('bundesland.json', 'w'))
